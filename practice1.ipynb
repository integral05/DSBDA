# %%
import pandas as pd
import numpy as np

df=pd.read_csv('country_wise_latest.csv')

# %% [markdown]
# SHOWS FIRST 10 ROWS

# %%
df.head(10)
# Out:
#         Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0          Afghanistan      36263    1269      25198    9796        106
# 1              Albania       4880     144       2745    1991        117
# 2              Algeria      27973    1163      18837    7973        616
# 3              Andorra        907      52        803      52         10
# 4               Angola        950      41        242     667         18
# 5  Antigua and Barbuda         86       3         65      18          4
# 6            Argentina     167416    3059      72575   91782       4890
# 7              Armenia      37390     711      26665   10014         73
# 8            Australia      15303     167       9311    5825        368
# 9              Austria      20558     713      18246    1599         86
#
#    New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0          10             18                3.50                  69.49
# ...

# %% [markdown]
# SHOWS LAST10 ROWS

# %%
df.tail(10)
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 177      United Kingdom     301708   45844       1437  254427        688
# 178             Uruguay       1202      35        951     216         10
# 179          Uzbekistan      21209     121      11674    9414        678
# 180           Venezuela      15988     146       9959    5883        525
# 181             Vietnam        431       0        365      66         11
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 177           7              3               15.19                   0.48
# ...

# %% [markdown]
# SHOWS COLUMNS NAME

# %%
df.columns
# Out:
# Index(['Country/Region', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'New cases', 'New deaths', 'New recovered', 'Deaths / 100 Cases',
#        'Recovered / 100 Cases', 'Deaths / 100 Recovered',
#        'Confirmed last week', '1 week change', '1 week % increase',
#        'WHO Region'],
#       dtype='object')

# %% [markdown]
# GIVES DATA IN PARTICCULAR COLUMN

# %%
df['Deaths']
# Out:
# 0      1269
# 1       144
# 2      1163
# 3        52
# 4        41
#        ...
# 182      78
# 183       1
# 184     483
# 185     140
# 186      36
# Name: Deaths, Length: 187, dtype: int64

# %%
df.Confirmed
# Out:
# 0      36263
# 1       4880
# 2      27973
# 3        907
# 4        950
#        ...
# 182    10621
# 183       10
# 184     1691
# 185     4552
# 186     2704
# Name: Confirmed, Length: 187, dtype: int64

# %%
df[['Country/Region','Deaths']]
# Out:
#          Country/Region  Deaths
# 0           Afghanistan    1269
# 1               Albania     144
# 2               Algeria    1163
# 3               Andorra      52
# 4                Angola      41
# ..                  ...     ...
# 182  West Bank and Gaza      78
# 183      Western Sahara       1
# 184               Yemen     483
# 185              Zambia     140
# 186            Zimbabwe      36
#
# [187 rows x 2 columns]

# %% [markdown]
# OPERATIONS ON DATA FRAMES

# %%
df.Recovered
# Out:
# 0      25198
# 1       2745
# 2      18837
# 3        803
# 4        242
#        ...
# 182     3752
# 183        8
# 184      833
# 185     2815
# 186      542
# Name: Recovered, Length: 187, dtype: int64

# %%
df.Recovered.min()
# Out:
# 0

# %%
df.Recovered.max()
# Out:
# 1846641

# %%
df.Recovered.mean()
# Out:
# 50631.48128342246

# %%
df.Recovered.std()
# Out:
# 190188.1896431397

# %%
df.describe()
# Out:
# C:\Users\tejas\AppData\Roaming\Python\Python311\site-packages\pandas\core\nanops.py:1010: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
#           Confirmed         Deaths     Recovered        Active     New cases  \
# count  1.870000e+02     187.000000  1.870000e+02  1.870000e+02    187.000000
# mean   8.813094e+04    3497.518717  5.063148e+04  3.400194e+04   1222.957219
# std    3.833187e+05   14100.002482  1.901882e+05  2.133262e+05   5710.374790
# min    1.000000e+01       0.000000  0.000000e+00  0.000000e+00      0.000000
# 25%    1.114000e+03      18.500000  6.265000e+02  1.415000e+02      4.000000
# 50%    5.059000e+03     108.000000  2.815000e+03  1.600000e+03     49.000000
# 75%    4.046050e+04     734.000000  2.260600e+04  9.149000e+03    419.500000
# max    4.290259e+06  148011.000000  1.846641e+06  2.816444e+06  56336.000000
#
#         New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
df.describe().T
# Out:
# C:\Users\tejas\AppData\Roaming\Python\Python311\site-packages\pandas\core\nanops.py:1010: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
#                         count          mean            std    min       25%  \
# Confirmed               187.0  8.813094e+04  383318.663831  10.00  1114.000
# Deaths                  187.0  3.497519e+03   14100.002482   0.00    18.500
# Recovered               187.0  5.063148e+04  190188.189643   0.00   626.500
# Active                  187.0  3.400194e+04  213326.173371   0.00   141.500
# New cases               187.0  1.222957e+03    5710.374790   0.00     4.000
# New deaths              187.0  2.895722e+01     120.037173   0.00     0.000
# New recovered           187.0  9.338128e+02    4197.719635   0.00     0.000
# Deaths / 100 Cases      187.0  3.019519e+00       3.454302   0.00     0.945
# Recovered / 100 Cases   187.0  6.482053e+01      26.287694   0.00    48.770
# ...

# %% [markdown]
# APPLYING CONDITIONS ON COLUMNS

# %%
df.Recovered>=1000
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 182     True
# 183    False
# 184    False
# 185     True
# 186    False
# Name: Recovered, Length: 187, dtype: bool

# %%
df[df.Recovered>=1000]
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 6             Argentina     167416    3059      72575   91782       4890
# 7               Armenia      37390     711      26665   10014         73
# ..                  ...        ...     ...        ...     ...        ...
# 177      United Kingdom     301708   45844       1437  254427        688
# 179          Uzbekistan      21209     121      11674    9414        678
# 180           Venezuela      15988     146       9959    5883        525
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 185              Zambia       4552     140       2815    1597         71
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
df[['Country/Region','Recovered']][df.Recovered>=1000]
# Out:
#          Country/Region  Recovered
# 0           Afghanistan      25198
# 1               Albania       2745
# 2               Algeria      18837
# 6             Argentina      72575
# 7               Armenia      26665
# ..                  ...        ...
# 177      United Kingdom       1437
# 179          Uzbekistan      11674
# 180           Venezuela       9959
# 182  West Bank and Gaza       3752
# 185              Zambia       2815
#
# [121 rows x 2 columns]

# %%
df[df.Recovered==df.Recovered.max()]
# Out:
#    Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 23         Brazil    2442375   87618    1846641  508116      23284
#
#     New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 23         614          33728                3.59                  75.61
#
#     Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 23                    4.74              2118646         323729
#
#     1 week % increase WHO Region
# 23              15.28   Americas

# %%
df[df.Recovered==df['Recovered'].max()]
# Out:
#    Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 23         Brazil    2442375   87618    1846641  508116      23284
#
#     New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 23         614          33728                3.59                  75.61
#
#     Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 23                    4.74              2118646         323729
#
#     1 week % increase WHO Region
# 23              15.28   Americas

# %%
df[['Country/Region','Recovered','Active']][df.Recovered==df["Recovered"].max()]
# Out:
#    Country/Region  Recovered  Active
# 23         Brazil    1846641  508116

# %% [markdown]
# WORKING ON INDEX

# %%
df.index
# Out:
# RangeIndex(start=0, stop=187, step=1)

# %% [markdown]
# SWITCHING INDEX TO PARTICULAR COLUMN

# %%
df.set_index('Country/Region')
# Out:
#                     Confirmed  Deaths  Recovered  Active  New cases  \
# Country/Region
# Afghanistan             36263    1269      25198    9796        106
# Albania                  4880     144       2745    1991        117
# Algeria                 27973    1163      18837    7973        616
# Andorra                   907      52        803      52         10
# Angola                    950      41        242     667         18
# ...                       ...     ...        ...     ...        ...
# West Bank and Gaza      10621      78       3752    6791        152
# Western Sahara             10       1          8       1          0
# Yemen                    1691     483        833     375         10
# Zambia                   4552     140       2815    1597         71
# Zimbabwe                 2704      36        542    2126        192
#
#                     New deaths  New recovered  Deaths / 100 Cases  \
# Country/Region
# ...

# %%
df.set_index('Country/Region',inplace=True)
df
# Out:
#                     Confirmed  Deaths  Recovered  Active  New cases  \
# Country/Region
# Afghanistan             36263    1269      25198    9796        106
# Albania                  4880     144       2745    1991        117
# Algeria                 27973    1163      18837    7973        616
# Andorra                   907      52        803      52         10
# Angola                    950      41        242     667         18
# ...                       ...     ...        ...     ...        ...
# West Bank and Gaza      10621      78       3752    6791        152
# Western Sahara             10       1          8       1          0
# Yemen                    1691     483        833     375         10
# Zambia                   4552     140       2815    1597         71
# Zimbabwe                 2704      36        542    2126        192
#
#                     New deaths  New recovered  Deaths / 100 Cases  \
# Country/Region
# ...

# %%
df.loc['India']
# Out:
# Confirmed                         1480073
# Deaths                              33408
# Recovered                          951166
# Active                             495499
# New cases                           44457
# New deaths                            637
# New recovered                       33598
# Deaths / 100 Cases                   2.26
# Recovered / 100 Cases               64.26
# Deaths / 100 Recovered               3.51
# Confirmed last week               1155338
# 1 week change                      324735
# 1 week % increase                   28.11
# WHO Region                South-East Asia
# Name: India, dtype: object

# %% [markdown]
# TO RESET THE INDEX

# %%
df.reset_index()
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...
